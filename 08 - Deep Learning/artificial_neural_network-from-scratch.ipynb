# %% [markdown]
# ## 1. Import libraries and datasets

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

dataset = pd.read_csv('Churn_Modelling.csv')
# CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary
x = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## 2. Encode Categorical data
#
# Label Encode the "Gender" column and One Hot Encode the "Geography" column

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# Gender encode
le = LabelEncoder()
x[:, 2] = le.fit_transform(x[:, 2])

# Geography column encode
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
# Geography (3), CreditScore, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary
x = np.array(ct.fit_transform(x))

# %% [markdown]
# ## 3. Preparing the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ## 4a. Train using Logistic Regression
#
# This is akin to a single "Neuron".
#
# Credits: [@kanncaa1](https://www.kaggle.com/kanncaa1/deep-learning-tutorial-for-beginners)
#
# <img src="https://sebastianraschka.com/images/faq/logisticregr-neuralnet/schematic.png" width="400" height="auto"/>
#
# (Source: [Sebastian Raschka, n.d.](https://sebastianraschka.com/faq/docs/logisticregr-neuralnet.html))

# %%
def sigmoid(z):
    return 1/(1 + np.exp(-z))

def euclidean_normalize(z, axis=0):
    return np.apply_along_axis(lambda a: np.sqrt(np.sum(np.power(a, 2))), axis, z)

def unit_step(y_values_pred):
    # The average becomes the threshold, because it is not returning 0.5 as threshold as it should.
    # Various reasons that can cause such is imbalanced data. For now the threshold is the (max - min) / 2. 
    pred_avg = (np.min(y_values_pred) + np.max(y_values_pred)) / 2
    return y_values_pred.flatten() > pred_avg, pred_avg

class LogisticRegression:
    
    def __init__(self, x_dimension):
        self.weights = np.full((x_dimension), 1/(10**3))
        self.bias = 0.0
        
    def activation_function(self, x_values):
        return sigmoid(np.dot(x_values, self.weights.T) + self.bias)

    def forward_propagation(self, x_values, y_values):
        # Use sigmoid activation function: Probabilistic value from 0-1
        y_computed = self.activation_function(x_values)
        # Use binary cross-entropy loss
        cost = np.sum(-y_values * np.log(y_computed) - (1 - y_values) * np.log(1 - y_computed)) / x_values.shape[0]     
        return y_computed, cost

    def backward_propagation(self, x_values, y_values, y_computed):
        y_derivative = y_computed - y_values
        # Apply linear combination (partial without sum) for each gradient * x input value
        x_values_gradient = np.array([x_values[i] * y_derivative[i] for i in range(x_values.shape[0])])
        # Sum all x input values which eventually divides by total rows
        x_values_hlc = np.array([np.sum(x_values_gradient[:,i]) for i in range(x_values_gradient.shape[1])]) / x_values.shape[0]

        # Derivative value of loss function with respect to weight
        weight_derivative = x_values_hlc / x_values.shape[1]

        # Derivative value of loss function with respect 
        bias_derivative = np.sum(y_derivative) / x_values.shape[1]
        return (weight_derivative, bias_derivative)

    def update_parameters(self, x_values, y_values, learning_rate=0.01, no_of_iterations=150):
        costs = []

        for i in range(no_of_iterations):
            y_computed, cost = self.forward_propagation(x_values, y_values)
            gradients = self.backward_propagation(x_values, y_values, y_computed)

            # Update weights and biases using batch gradient descent
            self.weights = self.weights - learning_rate * gradients[0]
            self.bias = self.bias - learning_rate * gradients[1]

            print(f'Cost for iteration {i + 1}: {cost}')
            costs.append(cost)

        return gradients, costs

    def predict(self, x_values):
        return np.array([self.activation_function([v])[0] for v in x_values])

model = LogisticRegression(x_train.shape[1])
_, costs = model.update_parameters(x_train, y_train, no_of_iterations=250)
# Out:
# Cost for iteration 1: 0.6931267316890196
# Cost for iteration 2: 0.5326591089930504
# Cost for iteration 3: 0.5061714423292546
# Cost for iteration 4: 0.5058058586589186
# Cost for iteration 5: 0.505780403921694
# Cost for iteration 6: 0.5057562592485311
# Cost for iteration 7: 0.5057321323585164
# Cost for iteration 8: 0.5057080141640107
# Cost for iteration 9: 0.5056839046002294
# Cost for iteration 10: 0.5056598036636925
# Cost for iteration 11: 0.5056357113513411
# Cost for iteration 12: 0.5056116276601199
# Cost for iteration 13: 0.5055875525869744
# Cost for iteration 14: 0.5055634861288505
# Cost for iteration 15: 0.5055394282826952
# Cost for iteration 16: 0.5055153790454561
# Cost for iteration 17: 0.5054913384140812
# Cost for iteration 18: 0.5054673063855198
# Cost for iteration 19: 0.5054432829567217
# Cost for iteration 20: 0.505419268124637
# Cost for iteration 21: 0.5053952618862173
# Cost for iteration 22: 0.5053712642384143
# Cost for iteration 23: 0.5053472751781807
# Cost for iteration 24: 0.5053232947024697
# Cost for iteration 25: 0.5052993228082359
# Cost for iteration 26: 0.5052753594924336
# Cost for iteration 27: 0.5052514047520187
# Cost for iteration 28: 0.5052274585839472
# Cost for iteration 29: 0.5052035209851764
# Cost for iteration 30: 0.5051795919526639
# Cost for iteration 31: 0.5051556714833683
# Cost for iteration 32: 0.5051317595742485
# Cost for iteration 33: 0.5051078562222648
# Cost for iteration 34: 0.5050839614243776
# Cost for iteration 35: 0.5050600751775486
# Cost for iteration 36: 0.5050361974787396
# Cost for iteration 37: 0.5050123283249136
# Cost for iteration 38: 0.5049884677130341
# Cost for iteration 39: 0.5049646156400657
# Cost for iteration 40: 0.5049407721029731
# Cost for iteration 41: 0.5049169370987222
# Cost for iteration 42: 0.5048931106242796
# Cost for iteration 43: 0.5048692926766125
# Cost for iteration 44: 0.5048454832526887
# Cost for iteration 45: 0.5048216823494773
# Cost for iteration 46: 0.5047978899639475
# Cost for iteration 47: 0.5047741060930694
# Cost for iteration 48: 0.5047503307338139
# Cost for iteration 49: 0.504726563883153
# Cost for iteration 50: 0.5047028055380586
# Cost for iteration 51: 0.5046790556955041
# Cost for iteration 52: 0.5046553143524632
# Cost for iteration 53: 0.5046315815059107
# Cost for iteration 54: 0.5046078571528217
# Cost for iteration 55: 0.5045841412901724
# Cost for iteration 56: 0.5045604339149394
# Cost for iteration 57: 0.5045367350241002
# Cost for iteration 58: 0.5045130446146334
# Cost for iteration 59: 0.5044893626835176
# Cost for iteration 60: 0.5044656892277327
# Cost for iteration 61: 0.5044420242442592
# Cost for iteration 62: 0.5044183677300782
# Cost for iteration 63: 0.5043947196821718
# Cost for iteration 64: 0.5043710800975223
# Cost for iteration 65: 0.5043474489731136
# Cost for iteration 66: 0.5043238263059294
# Cost for iteration 67: 0.504300212092955
# Cost for iteration 68: 0.5042766063311755
# Cost for iteration 69: 0.5042530090175777
# Cost for iteration 70: 0.5042294201491487
# Cost for iteration 71: 0.504205839722876
# Cost for iteration 72: 0.5041822677357485
# Cost for iteration 73: 0.5041587041847554
# Cost for iteration 74: 0.5041351490668866
# Cost for iteration 75: 0.5041116023791331
# Cost for iteration 76: 0.5040880641184864
# Cost for iteration 77: 0.5040645342819386
# Cost for iteration 78: 0.504041012866483
# Cost for iteration 79: 0.504017499869113
# Cost for iteration 80: 0.5039939952868234
# Cost for iteration 81: 0.5039704991166093
# Cost for iteration 82: 0.5039470113554667
# Cost for iteration 83: 0.5039235320003921
# Cost for iteration 84: 0.5039000610483834
# Cost for iteration 85: 0.5038765984964384
# Cost for iteration 86: 0.5038531443415563
# Cost for iteration 87: 0.5038296985807365
# Cost for iteration 88: 0.5038062612109796
# Cost for iteration 89: 0.5037828322292868
# Cost for iteration 90: 0.50375941163266
# Cost for iteration 91: 0.5037359994181017
# Cost for iteration 92: 0.5037125955826155
# Cost for iteration 93: 0.5036892001232053
# Cost for iteration 94: 0.5036658130368761
# Cost for iteration 95: 0.5036424343206336
# Cost for iteration 96: 0.503619063971484
# Cost for iteration 97: 0.5035957019864347
# Cost for iteration 98: 0.5035723483624931
# Cost for iteration 99: 0.5035490030966682
# Cost for iteration 100: 0.5035256661859692
# Cost for iteration 101: 0.503502337627406
# Cost for iteration 102: 0.5034790174179897
# Cost for iteration 103: 0.503455705554732
# Cost for iteration 104: 0.5034324020346447
# Cost for iteration 105: 0.5034091068547414
# Cost for iteration 106: 0.5033858200120357
# Cost for iteration 107: 0.503362541503542
# Cost for iteration 108: 0.5033392713262759
# Cost for iteration 109: 0.5033160094772532
# Cost for iteration 110: 0.5032927559534909
# Cost for iteration 111: 0.5032695107520063
# Cost for iteration 112: 0.503246273869818
# Cost for iteration 113: 0.5032230453039449
# Cost for iteration 114: 0.5031998250514067
# Cost for iteration 115: 0.5031766131092241
# Cost for iteration 116: 0.5031534094744182
# Cost for iteration 117: 0.5031302141440113
# Cost for iteration 118: 0.5031070271150259
# Cost for iteration 119: 0.5030838483844856
# Cost for iteration 120: 0.5030606779494149
# Cost for iteration 121: 0.5030375158068384
# Cost for iteration 122: 0.5030143619537824
# Cost for iteration 123: 0.5029912163872728
# Cost for iteration 124: 0.5029680791043375
# Cost for iteration 125: 0.5029449501020041
# Cost for iteration 126: 0.5029218293773015
# Cost for iteration 127: 0.5028987169272593
# Cost for iteration 128: 0.5028756127489077
# Cost for iteration 129: 0.5028525168392778
# Cost for iteration 130: 0.5028294291954012
# Cost for iteration 131: 0.5028063498143105
# Cost for iteration 132: 0.5027832786930391
# Cost for iteration 133: 0.5027602158286208
# Cost for iteration 134: 0.5027371612180908
# Cost for iteration 135: 0.502714114858484
# Cost for iteration 136: 0.5026910767468372
# Cost for iteration 137: 0.5026680468801873
# Cost for iteration 138: 0.5026450252555719
# Cost for iteration 139: 0.5026220118700298
# Cost for iteration 140: 0.5025990067206001
# Cost for iteration 141: 0.5025760098043229
# Cost for iteration 142: 0.5025530211182391
# Cost for iteration 143: 0.5025300406593901
# Cost for iteration 144: 0.5025070684248182
# Cost for iteration 145: 0.5024841044115665
# Cost for iteration 146: 0.502461148616679
# Cost for iteration 147: 0.5024382010371999
# Cost for iteration 148: 0.5024152616701748
# Cost for iteration 149: 0.5023923305126498
# Cost for iteration 150: 0.5023694075616714
# Cost for iteration 151: 0.5023464928142874
# Cost for iteration 152: 0.5023235862675461
# Cost for iteration 153: 0.5023006879184968
# Cost for iteration 154: 0.502277797764189
# Cost for iteration 155: 0.5022549158016735
# Cost for iteration 156: 0.5022320420280016
# Cost for iteration 157: 0.5022091764402254
# Cost for iteration 158: 0.5021863190353978
# Cost for iteration 159: 0.5021634698105724
# Cost for iteration 160: 0.5021406287628036
# Cost for iteration 161: 0.5021177958891466
# Cost for iteration 162: 0.5020949711866571
# Cost for iteration 163: 0.5020721546523919
# Cost for iteration 164: 0.5020493462834084
# Cost for iteration 165: 0.5020265460767647
# Cost for iteration 166: 0.5020037540295198
# Cost for iteration 167: 0.5019809701387332
# Cost for iteration 168: 0.5019581944014656
# Cost for iteration 169: 0.501935426814778
# Cost for iteration 170: 0.5019126673757325
# Cost for iteration 171: 0.5018899160813917
# Cost for iteration 172: 0.501867172928819
# Cost for iteration 173: 0.5018444379150786
# Cost for iteration 174: 0.5018217110372358
# Cost for iteration 175: 0.5017989922923561
# Cost for iteration 176: 0.5017762816775061
# Cost for iteration 177: 0.5017535791897528
# Cost for iteration 178: 0.5017308848261647
# Cost for iteration 179: 0.5017081985838101
# Cost for iteration 180: 0.5016855204597588
# Cost for iteration 181: 0.501662850451081
# Cost for iteration 182: 0.5016401885548479
# Cost for iteration 183: 0.5016175347681312
# Cost for iteration 184: 0.5015948890880035
# Cost for iteration 185: 0.5015722515115382
# Cost for iteration 186: 0.5015496220358092
# Cost for iteration 187: 0.5015270006578917
# Cost for iteration 188: 0.5015043873748609
# Cost for iteration 189: 0.5014817821837936
# Cost for iteration 190: 0.5014591850817667
# Cost for iteration 191: 0.5014365960658582
# Cost for iteration 192: 0.5014140151331467
# Cost for iteration 193: 0.5013914422807116
# Cost for iteration 194: 0.5013688775056333
# Cost for iteration 195: 0.5013463208049926
# Cost for iteration 196: 0.5013237721758712
# Cost for iteration 197: 0.5013012316153517
# Cost for iteration 198: 0.5012786991205173
# Cost for iteration 199: 0.5012561746884517
# Cost for iteration 200: 0.5012336583162401
# Cost for iteration 201: 0.5012111500009679
# Cost for iteration 202: 0.5011886497397213
# Cost for iteration 203: 0.5011661575295875
# Cost for iteration 204: 0.5011436733676543
# Cost for iteration 205: 0.5011211972510101
# Cost for iteration 206: 0.5010987291767445
# Cost for iteration 207: 0.5010762691419474
# Cost for iteration 208: 0.5010538171437098
# Cost for iteration 209: 0.5010313731791233
# Cost for iteration 210: 0.5010089372452803
# Cost for iteration 211: 0.5009865093392741
# Cost for iteration 212: 0.5009640894581985
# Cost for iteration 213: 0.5009416775991481
# Cost for iteration 214: 0.5009192737592186
# Cost for iteration 215: 0.5008968779355063
# Cost for iteration 216: 0.5008744901251079
# Cost for iteration 217: 0.5008521103251213
# Cost for iteration 218: 0.5008297385326451
# Cost for iteration 219: 0.5008073747447784
# Cost for iteration 220: 0.5007850189586216
# Cost for iteration 221: 0.500762671171275
# Cost for iteration 222: 0.5007403313798409
# Cost for iteration 223: 0.500717999581421
# Cost for iteration 224: 0.5006956757731189
# Cost for iteration 225: 0.5006733599520382
# Cost for iteration 226: 0.5006510521152837
# Cost for iteration 227: 0.5006287522599607
# Cost for iteration 228: 0.5006064603831756
# Cost for iteration 229: 0.5005841764820352
# Cost for iteration 230: 0.5005619005536475
# Cost for iteration 231: 0.5005396325951206
# Cost for iteration 232: 0.5005173726035639
# Cost for iteration 233: 0.5004951205760876
# Cost for iteration 234: 0.5004728765098024
# Cost for iteration 235: 0.5004506404018199
# Cost for iteration 236: 0.5004284122492524
# Cost for iteration 237: 0.500406192049213
# Cost for iteration 238: 0.5003839797988157
# Cost for iteration 239: 0.5003617754951749
# Cost for iteration 240: 0.5003395791354063
# Cost for iteration 241: 0.500317390716626
# Cost for iteration 242: 0.5002952102359508
# Cost for iteration 243: 0.5002730376904986
# Cost for iteration 244: 0.5002508730773878
# Cost for iteration 245: 0.5002287163937379
# Cost for iteration 246: 0.5002065676366685
# Cost for iteration 247: 0.5001844268033008
# Cost for iteration 248: 0.5001622938907562
# Cost for iteration 249: 0.500140168896157
# Cost for iteration 250: 0.5001180518166264

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score

def display_graph(graph_title):
    plt.plot(np.arange(len(costs)), costs, color='blue')
    plt.title(f'{graph_title} (Cost per Iter.)')
    plt.xlabel('Iteration')
    plt.ylabel('Cost')
    plt.show()

    y_pred_prob = model.predict(x_test)
    y_pred, y_pred_threshold = unit_step(y_pred_prob)

    y_test_1 = list(map(lambda a: a[1], filter(lambda a: y_test[a[0]] == 1, enumerate(y_pred_prob))))
    y_test_0 = list(map(lambda a: a[1], filter(lambda a: y_test[a[0]] == 0, enumerate(y_pred_prob))))

    plt.plot(np.arange(len(y_pred_prob)), sorted(y_pred_prob), color='blue')
    plt.axhline(y=y_pred_threshold, color='orange', linestyle='-')
    plt.title('Total Prediction score')
    plt.show()

    print(f'Threshold: {y_pred_threshold} (Min: {y_pred_prob.min()}, Max: {y_pred_prob.max()})\n')

    plt.scatter(np.arange(len(y_test_1)), y_test_1, facecolors='none', edgecolors='green', s=5)
    plt.axhline(y=y_pred_threshold, color='orange', linestyle='-')
    plt.title('Churned Prediction score')
    plt.show()

    plt.scatter(np.arange(len(y_test_0)), y_test_0, facecolors='none', edgecolors='red', s=5)
    plt.axhline(y=y_pred_threshold, color='orange', linestyle='-')
    plt.title('Not Churned Prediction score')
    plt.show()

    fig = plt.figure(figsize =(5, 3))
    ax = fig.add_axes([0, 0, 1, 1])
    ax.set_ylabel('Score')
    ax.set_title('Prediction score')
    ax.set_xticklabels(('Churned', 'Not Churned'))
    bp = ax.boxplot([
        [p for i, p in enumerate(y_pred_prob) if y_test[i] == 1],
        [p for i, p in enumerate(y_pred_prob) if y_test[i] == 0], 
    ])
    plt.show()

    outliers = [flier.get_ydata() for flier in bp['fliers']]
    medians = [median.get_ydata() for median in bp['medians']]
    whiskers = [whiskers.get_ydata() for whiskers in bp['whiskers']]

    print('\n', pd.DataFrame([
        list(map(lambda i: np.min(outliers[i]) if np.sum(outliers[i]) > 1 else 0, [0,1])),
        list(map(lambda i: np.max(outliers[i]) if np.sum(outliers[i]) > 1 else 0, [0,1])),
        list(map(lambda i: np.average(outliers[i]) if np.sum(outliers[i]) > 1 else 0, [0,1])),
        [whiskers[0][1], whiskers[2][1]],
        [whiskers[1][1], whiskers[3][1]],
        [whiskers[0][0], whiskers[2][0]],
        [medians[0][0], medians[1][0]],
        [whiskers[1][0], whiskers[3][0]]
    ], columns=['Churned', 'Not Churned'], index=['Outlier (min)', 'Outlier (max)', 'Outlier (avg)', 'Min', 'Max', 'Q1 (25%)', 'Q2 (50%, median)', 'Q3 (75%)']), '\n')

    cm = confusion_matrix(y_test, y_pred)

    nc_total = len(list(filter(lambda a: a == 0, y_test)))
    c_total = len(list(filter(lambda a: a == 1, y_test)))

    print(pd.DataFrame([
        list(cm[0]) + [cm[0][0] / nc_total, nc_total],
        list(cm[1]) + [cm[1][1] / c_total, c_total],

    ], columns=['Pred. Not Churned', 'Pred. Churned', 'Accuracy Score', 'Total'], index=['Not Churned', 'Churned']), '\n')
    print(f'Accuracy score: {accuracy_score(y_test, y_pred)} (Correct: {cm[0][0] + cm[1][1]}, Incorrect: {cm[0][1] + cm[1][0]})\n')

display_graph('Logistic Regression')
# Out:
# Threshold: 0.20800415789577803 (Min: 0.18809916280359776, Max: 0.22790915298795827)
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#                     Churned  Not Churned
# Outlier (min)     0.000000     0.220603
# Outlier (max)     0.000000     0.224000
# Outlier (avg)     0.000000     0.221833
# Min               0.189746     0.188965
# Max               0.227909     0.219899
# Q1 (25%)          0.204191     0.198644
# Q2 (50%, median)  0.208921     0.202370
# Q3 (75%)          0.214719     0.207171
#
#              Pred. Not Churned  Pred. Churned  Accuracy Score  Total
# Not Churned               1242            353        0.778683   1595
# Churned                    180            225        0.555556    405
#
# Accuracy score: 0.7335 (Correct: 1467, Incorrect: 533)

# %% [markdown]
# ## 4b. Train the 2-layer ANN model
#
# With a rough idea like this,
#
# <img src="http://media5.datahacker.rs/2018/08/tanh_sigma_activations.png" width="350" height="auto" />
#
# (Source: [datahacker.rs, 2018](http://datahacker.rs/activation-functions-and-derivatives/))

# %%
from random import random

class ANN2Layer:
    
    def __init__(self, x_dimension, y_dimension, no_of_neurons=6):
        self.weights_L1 = np.random.uniform(low=0, high=1/(10**3), size=(no_of_neurons, x_dimension))
        self.weights_L2 = np.random.uniform(low=0, high=1/(10**3), size=(y_dimension, no_of_neurons))
        self.bias_L1 = np.zeros((no_of_neurons, 1))
        self.bias_L2 = np.zeros((y_dimension, 1))

    def activation_function_L1(self, x_values):
        return np.tanh(np.dot(self.weights_L1, x_values.T) + self.bias_L1)
    
    def activation_function_L2(self, A1):
        return sigmoid(np.dot(self.weights_L2, A1) + self.bias_L2)

    def forward_propagation(self, x_values):
        A1 = self.activation_function_L1(x_values)
        A2 = self.activation_function_L2(A1)
        return A1, A2

    def backward_propagation(self, x_values, y_values, A1, A2):
        A2_derivative = A2 - y_values

        weights_L2_derivative = np.array([np.dot(A2_derivative, v.T) / x_values.shape[1] for v in A1]).T        
        bias_L2_derivative = np.sum(A2_derivative, axis=1, keepdims=True) / x_values.shape[1]
        
        A1_derivative = np.dot(self.weights_L2.T, A2_derivative) * (1 - np.power(A1, 2))

        # Apply gradients to each x in each neuron
        x_values_gradients = np.array([[x_values[j] * A1_derivative[i][j] for j in range(x_values.shape[0])] for i in range(A1_derivative.shape[0])])
        # Apply sum divided by no of x rows
        x_values_hlc = np.array([[np.sum(x_values_gradients[i][:,j]) / x_values.shape[0] for j in range(x_values.shape[1])] for i in range(A1_derivative.shape[0])])

        weights_L1_derivative = x_values_hlc / x_values.shape[1]
        bias_L1_derivative = np.sum(A1_derivative, axis=1, keepdims=True) / x_values.shape[1]

        return (weights_L1_derivative, bias_L1_derivative), (weights_L2_derivative, bias_L2_derivative)

    def update_parameters(self, x_values, y_values, learning_rate=0.01, no_of_iterations=150):
        costs = []
        
        for i in range(no_of_iterations):
            A1, A2 = self.forward_propagation(x_values)
            cost = -np.sum(np.multiply(np.log(A2), y_values)) / y_values.shape[0]
            A1_gradients, A2_gradients = self.backward_propagation(x_values, y_values, A1, A2)

            # Update weights and biases using batch gradient descent
            self.weights_L1 = self.weights_L1 - learning_rate * A1_gradients[0]
            self.bias_L1 = self.bias_L1 - learning_rate * A1_gradients[1]

            self.weights_L2 = self.weights_L2 - learning_rate * A2_gradients[0]
            self.bias_L2 = self.bias_L2 - learning_rate * A2_gradients[1]

            print(f'Cost for iteration {i + 1}: {cost}')
            costs.append(cost)
            
        return A1_gradients, A2_gradients, costs
    
    def predict(self, x_values):
        return np.array([np.sum(self.forward_propagation(np.array([v]))[1]) / self.weights_L2.shape[0] for v in x_values])


model = ANN2Layer(x_train.shape[1], 1)
_, _, costs = model.update_parameters(x_train, y_train, no_of_iterations=250)
# Out:
# Cost for iteration 1: 0.14140205430642888
# Cost for iteration 2: 0.4291097875134351
# Cost for iteration 3: 0.33497423236171053
# Cost for iteration 4: 0.32363108751395037
# Cost for iteration 5: 0.3243401977838426
# Cost for iteration 6: 0.3242807396654318
# Cost for iteration 7: 0.32428559862887585
# Cost for iteration 8: 0.3242851526682881
# Cost for iteration 9: 0.32428514459496716
# Cost for iteration 10: 0.3242851001225041
# Cost for iteration 11: 0.3242850583883108
# Cost for iteration 12: 0.3242850161310928
# Cost for iteration 13: 0.3242849735909172
# Cost for iteration 14: 0.32428493071847747
# Cost for iteration 15: 0.3242848874881593
# Cost for iteration 16: 0.32428484387216316
# Cost for iteration 17: 0.32428479984262243
# Cost for iteration 18: 0.3242847553714092
# Cost for iteration 19: 0.32428471043013085
# Cost for iteration 20: 0.3242846649901105
# Cost for iteration 21: 0.32428461902236894
# Cost for iteration 22: 0.32428457249760556
# Cost for iteration 23: 0.32428452538618047
# Cost for iteration 24: 0.3242844776580947
# Cost for iteration 25: 0.3242844292829717
# Cost for iteration 26: 0.3242843802300371
# Cost for iteration 27: 0.32428433046809985
# Cost for iteration 28: 0.3242842799655316
# Cost for iteration 29: 0.32428422869024726
# Cost for iteration 30: 0.3242841766096835
# Cost for iteration 31: 0.3242841236907792
# Cost for iteration 32: 0.3242840698999531
# Cost for iteration 33: 0.3242840152030833
# Cost for iteration 34: 0.3242839595654848
# Cost for iteration 35: 0.32428390295188797
# Cost for iteration 36: 0.32428384532641563
# Cost for iteration 37: 0.3242837866525606
# Cost for iteration 38: 0.3242837268931618
# Cost for iteration 39: 0.32428366601038133
# Cost for iteration 40: 0.3242836039656797
# Cost for iteration 41: 0.32428354071979154
# Cost for iteration 42: 0.3242834762327008
# Cost for iteration 43: 0.3242834104636152
# Cost for iteration 44: 0.3242833433709397
# Cost for iteration 45: 0.32428327491225095
# Cost for iteration 46: 0.3242832050442694
# Cost for iteration 47: 0.3242831337228326
# Cost for iteration 48: 0.3242830609028664
# Cost for iteration 49: 0.3242829865383567
# Cost for iteration 50: 0.32428291058232
# Cost for iteration 51: 0.3242828329867738
# Cost for iteration 52: 0.3242827537027056
# Cost for iteration 53: 0.324282672680042
# Cost for iteration 54: 0.3242825898676174
# Cost for iteration 55: 0.3242825052131405
# Cost for iteration 56: 0.3242824186631617
# Cost for iteration 57: 0.3242823301630391
# Cost for iteration 58: 0.3242822396569037
# Cost for iteration 59: 0.3242821470876238
# Cost for iteration 60: 0.32428205239676877
# Cost for iteration 61: 0.32428195552457245
# Cost for iteration 62: 0.3242818564098941
# Cost for iteration 63: 0.32428175499018075
# Cost for iteration 64: 0.32428165120142677
# Cost for iteration 65: 0.32428154497813344
# Cost for iteration 66: 0.32428143625326744
# Cost for iteration 67: 0.32428132495821826
# Cost for iteration 68: 0.3242812110227545
# Cost for iteration 69: 0.3242810943749795
# Cost for iteration 70: 0.3242809749412859
# Cost for iteration 71: 0.3242808526463084
# Cost for iteration 72: 0.3242807274128764
# Cost for iteration 73: 0.3242805991619649
# Cost for iteration 74: 0.32428046781264436
# Cost for iteration 75: 0.3242803332820295
# Cost for iteration 76: 0.3242801954852263
# Cost for iteration 77: 0.3242800543352788
# Cost for iteration 78: 0.32427990974311366
# Cost for iteration 79: 0.32427976161748334
# Cost for iteration 80: 0.32427960986490895
# Cost for iteration 81: 0.32427945438962036
# Cost for iteration 82: 0.32427929509349585
# Cost for iteration 83: 0.3242791318759996
# Cost for iteration 84: 0.32427896463411854
# Cost for iteration 85: 0.32427879326229647
# Cost for iteration 86: 0.3242786176523672
# Cost for iteration 87: 0.3242784376934866
# Cost for iteration 88: 0.32427825327206156
# Cost for iteration 89: 0.32427806427167866
# Cost for iteration 90: 0.32427787057303004
# Cost for iteration 91: 0.32427767205383806
# Cost for iteration 92: 0.3242774685887776
# Cost for iteration 93: 0.3242772600493968
# Cost for iteration 94: 0.3242770463040358
# Cost for iteration 95: 0.3242768272177432
# Cost for iteration 96: 0.3242766026521906
# Cost for iteration 97: 0.32427637246558527
# Cost for iteration 98: 0.32427613651257997
# Cost for iteration 99: 0.3242758946441812
# Cost for iteration 100: 0.3242756467076549
# Cost for iteration 101: 0.32427539254642956
# Cost for iteration 102: 0.3242751319999973
# Cost for iteration 103: 0.32427486490381235
# Cost for iteration 104: 0.3242745910891865
# Cost for iteration 105: 0.32427431038318305
# Cost for iteration 106: 0.3242740226085068
# Cost for iteration 107: 0.32427372758339207
# Cost for iteration 108: 0.32427342512148777
# Cost for iteration 109: 0.3242731150317397
# Cost for iteration 110: 0.3242727971182693
# Cost for iteration 111: 0.3242724711802501
# Cost for iteration 112: 0.3242721370117806
# Cost for iteration 113: 0.32427179440175435
# Cost for iteration 114: 0.324271443133726
# Cost for iteration 115: 0.324271082985775
# Cost for iteration 116: 0.3242707137303652
# Cost for iteration 117: 0.32427033513420067
# Cost for iteration 118: 0.32426994695807876
# Cost for iteration 119: 0.32426954895673915
# Cost for iteration 120: 0.32426914087870823
# Cost for iteration 121: 0.3242687224661408
# Cost for iteration 122: 0.32426829345465713
# Cost for iteration 123: 0.3242678535731759
# Cost for iteration 124: 0.3242674025437434
# Cost for iteration 125: 0.3242669400813576
# Cost for iteration 126: 0.3242664658937885
# Cost for iteration 127: 0.32426597968139403
# Cost for iteration 128: 0.3242654811369305
# Cost for iteration 129: 0.3242649699453589
# Cost for iteration 130: 0.3242644457836468
# Cost for iteration 131: 0.32426390832056345
# Cost for iteration 132: 0.3242633572164725
# Cost for iteration 133: 0.32426279212311626
# Cost for iteration 134: 0.3242622126833974
# Cost for iteration 135: 0.32426161853115354
# Cost for iteration 136: 0.3242610092909266
# Cost for iteration 137: 0.3242603845777262
# Cost for iteration 138: 0.3242597439967872
# Cost for iteration 139: 0.32425908714332163
# Cost for iteration 140: 0.324258413602263
# Cost for iteration 141: 0.32425772294800587
# Cost for iteration 142: 0.32425701474413804
# Cost for iteration 143: 0.3242562885431652
# Cost for iteration 144: 0.3242555438862306
# Cost for iteration 145: 0.32425478030282573
# Cost for iteration 146: 0.32425399731049503
# Cost for iteration 147: 0.32425319441453265
# Cost for iteration 148: 0.32425237110767124
# Cost for iteration 149: 0.32425152686976394
# Cost for iteration 150: 0.32425066116745743
# Cost for iteration 151: 0.32424977345385725
# Cost for iteration 152: 0.3242488631681844
# Cost for iteration 153: 0.32424792973542393
# Cost for iteration 154: 0.3242469725659639
# Cost for iteration 155: 0.324245991055226
# Cost for iteration 156: 0.32424498458328627
# Cost for iteration 157: 0.3242439525144873
# Cost for iteration 158: 0.32424289419703933
# Cost for iteration 159: 0.32424180896261284
# Cost for iteration 160: 0.32424069612591955
# Cost for iteration 161: 0.32423955498428436
# Cost for iteration 162: 0.3242383848172053
# Cost for iteration 163: 0.3242371848859033
# Cost for iteration 164: 0.32423595443286035
# Cost for iteration 165: 0.32423469268134636
# Cost for iteration 166: 0.3242333988349342
# Cost for iteration 167: 0.32423207207700216
# Cost for iteration 168: 0.3242307115702251
# Cost for iteration 169: 0.3242293164560513
# Cost for iteration 170: 0.32422788585416823
# Cost for iteration 171: 0.32422641886195325
# Cost for iteration 172: 0.3242249145539116
# Cost for iteration 173: 0.32422337198110096
# Cost for iteration 174: 0.3242217901705398
# Cost for iteration 175: 0.3242201681246032
# Cost for iteration 176: 0.3242185048204024
# Cost for iteration 177: 0.32421679920914914
# Cost for iteration 178: 0.32421505021550506
# Cost for iteration 179: 0.32421325673691376
# Cost for iteration 180: 0.3242114176429172
# Cost for iteration 181: 0.32420953177445494
# Cost for iteration 182: 0.3242075979431463
# Cost for iteration 183: 0.3242056149305541
# Cost for iteration 184: 0.32420358148743156
# Cost for iteration 185: 0.3242014963329491
# Cost for iteration 186: 0.32419935815390327
# Cost for iteration 187: 0.32419716560390593
# Cost for iteration 188: 0.3241949173025531
# Cost for iteration 189: 0.32419261183457393
# Cost for iteration 190: 0.32419024774895866
# Cost for iteration 191: 0.324187823558065
# Cost for iteration 192: 0.3241853377367031
# Cost for iteration 193: 0.32418278872119755
# Cost for iteration 194: 0.3241801749084268
# Cost for iteration 195: 0.3241774946548399
# Cost for iteration 196: 0.32417474627544757
# Cost for iteration 197: 0.3241719280427901
# Cost for iteration 198: 0.32416903818588017
# Cost for iteration 199: 0.32416607488911914
# Cost for iteration 200: 0.32416303629118765
# Cost for iteration 201: 0.32415992048390985
# Cost for iteration 202: 0.32415672551108865
# Cost for iteration 203: 0.3241534493673147
# Cost for iteration 204: 0.3241500899967452
# Cost for iteration 205: 0.3241466452918549
# Cost for iteration 206: 0.32414311309215454
# Cost for iteration 207: 0.3241394911828819
# Cost for iteration 208: 0.3241357772936585
# Cost for iteration 209: 0.324131969097116
# Cost for iteration 210: 0.3241280642074893
# Cost for iteration 211: 0.3241240601791759
# Cost for iteration 212: 0.32411995450526143
# Cost for iteration 213: 0.32411574461601006
# Cost for iteration 214: 0.3241114278773188
# Cost for iteration 215: 0.3241070015891361
# Cost for iteration 216: 0.324102462983842
# Cost for iteration 217: 0.3240978092245919
# Cost for iteration 218: 0.32409303740361944
# Cost for iteration 219: 0.32408814454050117
# Cost for iteration 220: 0.32408312758038016
# Cost for iteration 221: 0.3240779833921481
# Cost for iteration 222: 0.3240727087665855
# Cost for iteration 223: 0.3240673004144587
# Cost for iteration 224: 0.32406175496457285
# Cost for iteration 225: 0.3240560689617801
# Cost for iteration 226: 0.3240502388649418
# Cost for iteration 227: 0.32404426104484485
# Cost for iteration 228: 0.3240381317820697
# Cost for iteration 229: 0.3240318472648104
# Cost for iteration 230: 0.3240254035866448
# Cost for iteration 231: 0.32401879674425493
# Cost for iteration 232: 0.324012022635096
# Cost for iteration 233: 0.3240050770550129
# Cost for iteration 234: 0.32399795569580403
# Cost for iteration 235: 0.3239906541427305
# Cost for iteration 236: 0.32398316787197085
# Cost for iteration 237: 0.32397549224801936
# Cost for iteration 238: 0.32396762252102745
# Cost for iteration 239: 0.32395955382408725
# Cost for iteration 240: 0.32395128117045613
# Cost for iteration 241: 0.3239427994507215
# Cost for iteration 242: 0.3239341034299048
# Cost for iteration 243: 0.32392518774450363
# Cost for iteration 244: 0.32391604689947123
# Cost for iteration 245: 0.32390667526513245
# Cost for iteration 246: 0.323897067074035
# Cost for iteration 247: 0.32388721641773527
# Cost for iteration 248: 0.32387711724351786
# Cost for iteration 249: 0.32386676335104825
# Cost for iteration 250: 0.32385614838895604

# %%
display_graph('2-layer ANN')
# Out:
# Threshold: 0.2042256324338565 (Min: 0.2023593823009897, Max: 0.20609188256672326)
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: FixedFormatter should only be used together with FixedLocator
#                     Churned  Not Churned
# Outlier (min)     0.000000     0.000000
# Outlier (max)     0.000000     0.000000
# Outlier (avg)     0.000000     0.000000
# Min               0.202861     0.202408
# Max               0.206092     0.205439
# Q1 (25%)          0.204067     0.203507
# Q2 (50%, median)  0.204472     0.203890
# Q3 (75%)          0.204928     0.204296
#
#              Pred. Not Churned  Pred. Churned  Accuracy Score  Total
# Not Churned               1137            458        0.712853   1595
# Churned                    141            264        0.651852    405
#
# Accuracy score: 0.7005 (Correct: 1401, Incorrect: 599)
